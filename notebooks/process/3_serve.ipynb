# %% [markdown]
# # Serve Model
#
# ## Story
# * We have a fully trained TensorFlow model
# * TensorFlow models are ideal to bring them into production
# * The model is stored as a computational graph and can be executed pretty much anywhere
#   1. We can just load the saved model and exeute it from Python or
#   1. There is a specific CC built server that can just serve it
#   1. It will run in the Cloud as is
#   1. Can be integrated into Java
# * Even Docker can be made to have access to GPU
# * Large models train very nicely, but can be unfortunate in production
#   * Unfortunately, so far, only model size can be brought down, but not latency: https://github.com/tensorflow/model-optimization/issues/173
#   * TFLite models do support latency speedup: https://www.tensorflow.org/model_optimization/guide/pruning/pruning_for_on_device_inference

# %%
# !ls -l classifier
# Out:
# total 280
# drwxr-xr-x 1 olive 197609      0 Jan 31 17:36 assets
# -rw-r--r-- 1 olive 197609  19134 Jan 31 17:39 keras_metadata.pb
# -rw-r--r-- 1 olive 197609 261883 Jan 31 17:39 saved_model.pb
# drwxr-xr-x 1 olive 197609      0 Jan 31 17:39 variables

# %% [markdown]
# ## Load and use model from Python

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
tf.__version__
# Out:
# '2.7.0'

# %%
# https://www.tensorflow.org/guide/keras/save_and_serialize

reconstructed_model = tf.keras.models.load_model("classifier")
reconstructed_model

# %%
tf.keras.utils.plot_model(reconstructed_model, show_shapes=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
reconstructed_model.signatures
# Out:
# _SignatureMap({'serving_default': <ConcreteFunction signature_wrapper(*, input) at 0x13701DC67C0>})

# %%
inference_fn = reconstructed_model.signatures['serving_default']
inference_fn
# Out:
# <ConcreteFunction signature_wrapper(*, input) at 0x13701DC67C0>

# %%
t = tf.convert_to_tensor([[48, 100]], dtype=tf.float32)
t
# Out:
# <tf.Tensor: shape=(1, 2), dtype=float32, numpy=array([[ 48., 100.]], dtype=float32)>

# %%
# %%time

inference_fn(input=t)
# Out:
# Wall time: 42.2 ms
# {'output': <tf.Tensor: shape=(1, 3), dtype=float32, numpy=array([[0.02230324, 0.24661334, 0.7310834 ]], dtype=float32)>}

# %%
# * https://www.tensorflow.org/guide/intro_to_graphs
# * https://www.tensorflow.org/api_docs/python/tf/Graph#as_graph_def 

# The serialized GraphDef can be imported into another Graph (using tf.import_graph_def) or used with the C++ Session API.

graph = inference_fn.graph.as_graph_def()
type(graph)
# Out:
# tensorflow.core.framework.graph_pb2.GraphDef

# %%
graph
# Out:
# node {
#   name: "input"
#   op: "Placeholder"
#   attr {
#     key: "_user_specified_name"
#     value {
#       s: "input"
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: -1
#         }
#         dim {
#           size: 2
#         }
#       }
#     }
#   }
# }
# node {
#   name: "unknown"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_RESOURCE
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "unknown_0"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_RESOURCE
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "unknown_1"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_RESOURCE
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "unknown_2"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_RESOURCE
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "unknown_3"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_RESOURCE
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "unknown_4"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_RESOURCE
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "unknown_5"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_RESOURCE
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "unknown_6"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_RESOURCE
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "unknown_7"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_RESOURCE
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "unknown_8"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_RESOURCE
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "unknown_9"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_RESOURCE
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "unknown_10"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_RESOURCE
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "unknown_11"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_RESOURCE
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "unknown_12"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_RESOURCE
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "unknown_13"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_RESOURCE
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "unknown_14"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_RESOURCE
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "unknown_15"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_RESOURCE
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "unknown_16"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_RESOURCE
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "unknown_17"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_RESOURCE
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "unknown_18"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_RESOURCE
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "StatefulPartitionedCall"
#   op: "StatefulPartitionedCall"
#   input: "input"
#   input: "unknown"
#   input: "unknown_0"
#   input: "unknown_1"
#   input: "unknown_2"
#   input: "unknown_3"
#   input: "unknown_4"
#   input: "unknown_5"
#   input: "unknown_6"
#   input: "unknown_7"
#   input: "unknown_8"
#   input: "unknown_9"
#   input: "unknown_10"
#   input: "unknown_11"
#   input: "unknown_12"
#   input: "unknown_13"
#   input: "unknown_14"
#   input: "unknown_15"
#   input: "unknown_16"
#   input: "unknown_17"
#   input: "unknown_18"
#   attr {
#     key: "Tin"
#     value {
#       list {
#         type: DT_FLOAT
#         type: DT_RESOURCE
#         type: DT_RESOURCE
#         type: DT_RESOURCE
#         type: DT_RESOURCE
#         type: DT_RESOURCE
#         type: DT_RESOURCE
#         type: DT_RESOURCE
#         type: DT_RESOURCE
#         type: DT_RESOURCE
#         type: DT_RESOURCE
#         type: DT_RESOURCE
#         type: DT_RESOURCE
#         type: DT_RESOURCE
#         type: DT_RESOURCE
#         type: DT_RESOURCE
#         type: DT_RESOURCE
#         type: DT_RESOURCE
#         type: DT_RESOURCE
#         type: DT_RESOURCE
#         type: DT_RESOURCE
#       }
#     }
#   }
#   attr {
#     key: "Tout"
#     value {
#       list {
#         type: DT_FLOAT
#       }
#     }
#   }
#   attr {
#     key: "_collective_manager_ids"
#     value {
#       list {
#       }
#     }
#   }
#   attr {
#     key: "_read_only_resource_inputs"
#     value {
#       list {
#         i: 1
#         i: 2
#         i: 3
#         i: 4
#         i: 5
#         i: 6
#         i: 7
#         i: 8
#         i: 9
#         i: 10
#         i: 11
#         i: 12
#         i: 13
#         i: 14
#         i: 15
#         i: 16
#         i: 17
#         i: 18
#         i: 19
#         i: 20
#       }
#     }
#   }
#   attr {
#     key: "config"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "config_proto"
#     value {
#       s: "\n\007\n\003CPU\020\001\n\007\n\003GPU\020\0002\002J\0008\001\202\001\000"
#     }
#   }
#   attr {
#     key: "executor_type"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "f"
#     value {
#       func {
#         name: "__inference__wrapped_model_415"
#       }
#     }
#   }
# }
# node {
#   name: "NoOp"
#   op: "NoOp"
#   input: "^StatefulPartitionedCall"
#   attr {
#     key: "_acd_function_control_output"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "Identity"
#   op: "Identity"
#   input: "StatefulPartitionedCall"
#   input: "^NoOp"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# library {
#   function {
#     signature {
#       name: "__inference__wrapped_model_415"
#       input_arg {
#         name: "input"
#         type: DT_FLOAT
#       }
#       input_arg {
#         name: "sequential_hidden1_matmul_readvariableop_resource"
#         type: DT_RESOURCE
#       }
#       input_arg {
#         name: "sequential_hidden1_biasadd_readvariableop_resource"
#         type: DT_RESOURCE
#       }
#       input_arg {
#         name: "sequential_batch_normalization_batchnorm_readvariableop_resource"
#         type: DT_RESOURCE
#       }
#       input_arg {
#         name: "sequential_batch_normalization_batchnorm_mul_readvariableop_resource"
#         type: DT_RESOURCE
#       }
#       input_arg {
#         name: "sequential_batch_normalization_batchnorm_readvariableop_1_resource"
#         type: DT_RESOURCE
#       }
#       input_arg {
#         name: "sequential_batch_normalization_batchnorm_readvariableop_2_resource"
#         type: DT_RESOURCE
#       }
#       input_arg {
#         name: "sequential_hidden2_matmul_readvariableop_resource"
#         type: DT_RESOURCE
#       }
#       input_arg {
#         name: "sequential_hidden2_biasadd_readvariableop_resource"
#         type: DT_RESOURCE
#       }
#       input_arg {
#         name: "sequential_batch_normalization_1_batchnorm_readvariableop_resource"
#         type: DT_RESOURCE
#       }
#       input_arg {
#         name: "sequential_batch_normalization_1_batchnorm_mul_readvariableop_resource"
#         type: DT_RESOURCE
#       }
#       input_arg {
#         name: "sequential_batch_normalization_1_batchnorm_readvariableop_1_resource"
#         type: DT_RESOURCE
#       }
#       input_arg {
#         name: "sequential_batch_normalization_1_batchnorm_readvariableop_2_resource"
#         type: DT_RESOURCE
#       }
#       input_arg {
#         name: "sequential_hidden3_matmul_readvariableop_resource"
#         type: DT_RESOURCE
#       }
#       input_arg {
#         name: "sequential_hidden3_biasadd_readvariableop_resource"
#         type: DT_RESOURCE
#       }
#       input_arg {
#         name: "sequential_batch_normalization_2_batchnorm_readvariableop_resource"
#         type: DT_RESOURCE
#       }
#       input_arg {
#         name: "sequential_batch_normalization_2_batchnorm_mul_readvariableop_resource"
#         type: DT_RESOURCE
#       }
#       input_arg {
#         name: "sequential_batch_normalization_2_batchnorm_readvariableop_1_resource"
#         type: DT_RESOURCE
#       }
#       input_arg {
#         name: "sequential_batch_normalization_2_batchnorm_readvariableop_2_resource"
#         type: DT_RESOURCE
#       }
#       input_arg {
#         name: "sequential_output_matmul_readvariableop_resource"
#         type: DT_RESOURCE
#       }
#       input_arg {
#         name: "sequential_output_biasadd_readvariableop_resource"
#         type: DT_RESOURCE
#       }
#       output_arg {
#         name: "identity"
#         type: DT_FLOAT
#       }
#       is_stateful: true
#       control_output: "sequential/batch_normalization/batchnorm/ReadVariableOp"
#       control_output: "sequential/batch_normalization/batchnorm/ReadVariableOp_1"
#       control_output: "sequential/batch_normalization/batchnorm/ReadVariableOp_2"
#       control_output: "sequential/batch_normalization/batchnorm/mul/ReadVariableOp"
#       control_output: "sequential/batch_normalization_1/batchnorm/ReadVariableOp"
#       control_output: "sequential/batch_normalization_1/batchnorm/ReadVariableOp_1"
#       control_output: "sequential/batch_normalization_1/batchnorm/ReadVariableOp_2"
#       control_output: "sequential/batch_normalization_1/batchnorm/mul/ReadVariableOp"
#       control_output: "sequential/batch_normalization_2/batchnorm/ReadVariableOp"
#       control_output: "sequential/batch_normalization_2/batchnorm/ReadVariableOp_1"
#       control_output: "sequential/batch_normalization_2/batchnorm/ReadVariableOp_2"
#       control_output: "sequential/batch_normalization_2/batchnorm/mul/ReadVariableOp"
#       control_output: "sequential/hidden1/BiasAdd/ReadVariableOp"
#       control_output: "sequential/hidden1/MatMul/ReadVariableOp"
#       control_output: "sequential/hidden2/BiasAdd/ReadVariableOp"
#       control_output: "sequential/hidden2/MatMul/ReadVariableOp"
#       control_output: "sequential/hidden3/BiasAdd/ReadVariableOp"
#       control_output: "sequential/hidden3/MatMul/ReadVariableOp"
#       control_output: "sequential/output/BiasAdd/ReadVariableOp"
#       control_output: "sequential/output/MatMul/ReadVariableOp"
#     }
#     node_def {
#       name: "sequential/hidden1/MatMul/ReadVariableOp"
#       op: "ReadVariableOp"
#       input: "sequential_hidden1_matmul_readvariableop_resource"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/hidden1/MatMul"
#       op: "MatMul"
#       input: "input"
#       input: "sequential/hidden1/MatMul/ReadVariableOp:value:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#       attr {
#         key: "transpose_a"
#         value {
#           b: false
#         }
#       }
#       attr {
#         key: "transpose_b"
#         value {
#           b: false
#         }
#       }
#     }
#     node_def {
#       name: "sequential/hidden1/BiasAdd/ReadVariableOp"
#       op: "ReadVariableOp"
#       input: "sequential_hidden1_biasadd_readvariableop_resource"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/hidden1/BiasAdd"
#       op: "BiasAdd"
#       input: "sequential/hidden1/MatMul:product:0"
#       input: "sequential/hidden1/BiasAdd/ReadVariableOp:value:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#       attr {
#         key: "data_format"
#         value {
#           s: "NHWC"
#         }
#       }
#     }
#     node_def {
#       name: "sequential/activation/Relu"
#       op: "Relu"
#       input: "sequential/hidden1/BiasAdd:output:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization/batchnorm/ReadVariableOp"
#       op: "ReadVariableOp"
#       input: "sequential_batch_normalization_batchnorm_readvariableop_resource"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization/batchnorm/add/y"
#       op: "Const"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_FLOAT
#         }
#       }
#       attr {
#         key: "value"
#         value {
#           tensor {
#             dtype: DT_FLOAT
#             tensor_shape {
#             }
#             float_val: 0.0010000000474974513
#           }
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization/batchnorm/add"
#       op: "AddV2"
#       input: "sequential/batch_normalization/batchnorm/ReadVariableOp:value:0"
#       input: "sequential/batch_normalization/batchnorm/add/y:output:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization/batchnorm/Rsqrt"
#       op: "Rsqrt"
#       input: "sequential/batch_normalization/batchnorm/add:z:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization/batchnorm/mul/ReadVariableOp"
#       op: "ReadVariableOp"
#       input: "sequential_batch_normalization_batchnorm_mul_readvariableop_resource"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization/batchnorm/mul"
#       op: "Mul"
#       input: "sequential/batch_normalization/batchnorm/Rsqrt:y:0"
#       input: "sequential/batch_normalization/batchnorm/mul/ReadVariableOp:value:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization/batchnorm/mul_1"
#       op: "Mul"
#       input: "sequential/activation/Relu:activations:0"
#       input: "sequential/batch_normalization/batchnorm/mul:z:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization/batchnorm/ReadVariableOp_1"
#       op: "ReadVariableOp"
#       input: "sequential_batch_normalization_batchnorm_readvariableop_1_resource"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization/batchnorm/mul_2"
#       op: "Mul"
#       input: "sequential/batch_normalization/batchnorm/ReadVariableOp_1:value:0"
#       input: "sequential/batch_normalization/batchnorm/mul:z:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization/batchnorm/ReadVariableOp_2"
#       op: "ReadVariableOp"
#       input: "sequential_batch_normalization_batchnorm_readvariableop_2_resource"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization/batchnorm/sub"
#       op: "Sub"
#       input: "sequential/batch_normalization/batchnorm/ReadVariableOp_2:value:0"
#       input: "sequential/batch_normalization/batchnorm/mul_2:z:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization/batchnorm/add_1"
#       op: "AddV2"
#       input: "sequential/batch_normalization/batchnorm/mul_1:z:0"
#       input: "sequential/batch_normalization/batchnorm/sub:z:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/hidden2/MatMul/ReadVariableOp"
#       op: "ReadVariableOp"
#       input: "sequential_hidden2_matmul_readvariableop_resource"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/hidden2/MatMul"
#       op: "MatMul"
#       input: "sequential/batch_normalization/batchnorm/add_1:z:0"
#       input: "sequential/hidden2/MatMul/ReadVariableOp:value:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#       attr {
#         key: "transpose_a"
#         value {
#           b: false
#         }
#       }
#       attr {
#         key: "transpose_b"
#         value {
#           b: false
#         }
#       }
#     }
#     node_def {
#       name: "sequential/hidden2/BiasAdd/ReadVariableOp"
#       op: "ReadVariableOp"
#       input: "sequential_hidden2_biasadd_readvariableop_resource"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/hidden2/BiasAdd"
#       op: "BiasAdd"
#       input: "sequential/hidden2/MatMul:product:0"
#       input: "sequential/hidden2/BiasAdd/ReadVariableOp:value:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#       attr {
#         key: "data_format"
#         value {
#           s: "NHWC"
#         }
#       }
#     }
#     node_def {
#       name: "sequential/activation_1/Relu"
#       op: "Relu"
#       input: "sequential/hidden2/BiasAdd:output:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization_1/batchnorm/ReadVariableOp"
#       op: "ReadVariableOp"
#       input: "sequential_batch_normalization_1_batchnorm_readvariableop_resource"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization_1/batchnorm/add/y"
#       op: "Const"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_FLOAT
#         }
#       }
#       attr {
#         key: "value"
#         value {
#           tensor {
#             dtype: DT_FLOAT
#             tensor_shape {
#             }
#             float_val: 0.0010000000474974513
#           }
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization_1/batchnorm/add"
#       op: "AddV2"
#       input: "sequential/batch_normalization_1/batchnorm/ReadVariableOp:value:0"
#       input: "sequential/batch_normalization_1/batchnorm/add/y:output:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization_1/batchnorm/Rsqrt"
#       op: "Rsqrt"
#       input: "sequential/batch_normalization_1/batchnorm/add:z:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization_1/batchnorm/mul/ReadVariableOp"
#       op: "ReadVariableOp"
#       input: "sequential_batch_normalization_1_batchnorm_mul_readvariableop_resource"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization_1/batchnorm/mul"
#       op: "Mul"
#       input: "sequential/batch_normalization_1/batchnorm/Rsqrt:y:0"
#       input: "sequential/batch_normalization_1/batchnorm/mul/ReadVariableOp:value:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization_1/batchnorm/mul_1"
#       op: "Mul"
#       input: "sequential/activation_1/Relu:activations:0"
#       input: "sequential/batch_normalization_1/batchnorm/mul:z:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization_1/batchnorm/ReadVariableOp_1"
#       op: "ReadVariableOp"
#       input: "sequential_batch_normalization_1_batchnorm_readvariableop_1_resource"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization_1/batchnorm/mul_2"
#       op: "Mul"
#       input: "sequential/batch_normalization_1/batchnorm/ReadVariableOp_1:value:0"
#       input: "sequential/batch_normalization_1/batchnorm/mul:z:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization_1/batchnorm/ReadVariableOp_2"
#       op: "ReadVariableOp"
#       input: "sequential_batch_normalization_1_batchnorm_readvariableop_2_resource"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization_1/batchnorm/sub"
#       op: "Sub"
#       input: "sequential/batch_normalization_1/batchnorm/ReadVariableOp_2:value:0"
#       input: "sequential/batch_normalization_1/batchnorm/mul_2:z:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization_1/batchnorm/add_1"
#       op: "AddV2"
#       input: "sequential/batch_normalization_1/batchnorm/mul_1:z:0"
#       input: "sequential/batch_normalization_1/batchnorm/sub:z:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/hidden3/MatMul/ReadVariableOp"
#       op: "ReadVariableOp"
#       input: "sequential_hidden3_matmul_readvariableop_resource"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/hidden3/MatMul"
#       op: "MatMul"
#       input: "sequential/batch_normalization_1/batchnorm/add_1:z:0"
#       input: "sequential/hidden3/MatMul/ReadVariableOp:value:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#       attr {
#         key: "transpose_a"
#         value {
#           b: false
#         }
#       }
#       attr {
#         key: "transpose_b"
#         value {
#           b: false
#         }
#       }
#     }
#     node_def {
#       name: "sequential/hidden3/BiasAdd/ReadVariableOp"
#       op: "ReadVariableOp"
#       input: "sequential_hidden3_biasadd_readvariableop_resource"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/hidden3/BiasAdd"
#       op: "BiasAdd"
#       input: "sequential/hidden3/MatMul:product:0"
#       input: "sequential/hidden3/BiasAdd/ReadVariableOp:value:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#       attr {
#         key: "data_format"
#         value {
#           s: "NHWC"
#         }
#       }
#     }
#     node_def {
#       name: "sequential/activation_2/Relu"
#       op: "Relu"
#       input: "sequential/hidden3/BiasAdd:output:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization_2/batchnorm/ReadVariableOp"
#       op: "ReadVariableOp"
#       input: "sequential_batch_normalization_2_batchnorm_readvariableop_resource"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization_2/batchnorm/add/y"
#       op: "Const"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_FLOAT
#         }
#       }
#       attr {
#         key: "value"
#         value {
#           tensor {
#             dtype: DT_FLOAT
#             tensor_shape {
#             }
#             float_val: 0.0010000000474974513
#           }
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization_2/batchnorm/add"
#       op: "AddV2"
#       input: "sequential/batch_normalization_2/batchnorm/ReadVariableOp:value:0"
#       input: "sequential/batch_normalization_2/batchnorm/add/y:output:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization_2/batchnorm/Rsqrt"
#       op: "Rsqrt"
#       input: "sequential/batch_normalization_2/batchnorm/add:z:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization_2/batchnorm/mul/ReadVariableOp"
#       op: "ReadVariableOp"
#       input: "sequential_batch_normalization_2_batchnorm_mul_readvariableop_resource"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization_2/batchnorm/mul"
#       op: "Mul"
#       input: "sequential/batch_normalization_2/batchnorm/Rsqrt:y:0"
#       input: "sequential/batch_normalization_2/batchnorm/mul/ReadVariableOp:value:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization_2/batchnorm/mul_1"
#       op: "Mul"
#       input: "sequential/activation_2/Relu:activations:0"
#       input: "sequential/batch_normalization_2/batchnorm/mul:z:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization_2/batchnorm/ReadVariableOp_1"
#       op: "ReadVariableOp"
#       input: "sequential_batch_normalization_2_batchnorm_readvariableop_1_resource"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization_2/batchnorm/mul_2"
#       op: "Mul"
#       input: "sequential/batch_normalization_2/batchnorm/ReadVariableOp_1:value:0"
#       input: "sequential/batch_normalization_2/batchnorm/mul:z:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization_2/batchnorm/ReadVariableOp_2"
#       op: "ReadVariableOp"
#       input: "sequential_batch_normalization_2_batchnorm_readvariableop_2_resource"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization_2/batchnorm/sub"
#       op: "Sub"
#       input: "sequential/batch_normalization_2/batchnorm/ReadVariableOp_2:value:0"
#       input: "sequential/batch_normalization_2/batchnorm/mul_2:z:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/batch_normalization_2/batchnorm/add_1"
#       op: "AddV2"
#       input: "sequential/batch_normalization_2/batchnorm/mul_1:z:0"
#       input: "sequential/batch_normalization_2/batchnorm/sub:z:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/output/MatMul/ReadVariableOp"
#       op: "ReadVariableOp"
#       input: "sequential_output_matmul_readvariableop_resource"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/output/MatMul"
#       op: "MatMul"
#       input: "sequential/batch_normalization_2/batchnorm/add_1:z:0"
#       input: "sequential/output/MatMul/ReadVariableOp:value:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#       attr {
#         key: "transpose_a"
#         value {
#           b: false
#         }
#       }
#       attr {
#         key: "transpose_b"
#         value {
#           b: false
#         }
#       }
#     }
#     node_def {
#       name: "sequential/output/BiasAdd/ReadVariableOp"
#       op: "ReadVariableOp"
#       input: "sequential_output_biasadd_readvariableop_resource"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "sequential/output/BiasAdd"
#       op: "BiasAdd"
#       input: "sequential/output/MatMul:product:0"
#       input: "sequential/output/BiasAdd/ReadVariableOp:value:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#       attr {
#         key: "data_format"
#         value {
#           s: "NHWC"
#         }
#       }
#     }
#     node_def {
#       name: "sequential/output/Softmax"
#       op: "Softmax"
#       input: "sequential/output/BiasAdd:output:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "NoOp"
#       op: "NoOp"
#       input: "^sequential/batch_normalization/batchnorm/ReadVariableOp"
#       input: "^sequential/batch_normalization/batchnorm/ReadVariableOp_1"
#       input: "^sequential/batch_normalization/batchnorm/ReadVariableOp_2"
#       input: "^sequential/batch_normalization/batchnorm/mul/ReadVariableOp"
#       input: "^sequential/batch_normalization_1/batchnorm/ReadVariableOp"
#       input: "^sequential/batch_normalization_1/batchnorm/ReadVariableOp_1"
#       input: "^sequential/batch_normalization_1/batchnorm/ReadVariableOp_2"
#       input: "^sequential/batch_normalization_1/batchnorm/mul/ReadVariableOp"
#       input: "^sequential/batch_normalization_2/batchnorm/ReadVariableOp"
#       input: "^sequential/batch_normalization_2/batchnorm/ReadVariableOp_1"
#       input: "^sequential/batch_normalization_2/batchnorm/ReadVariableOp_2"
#       input: "^sequential/batch_normalization_2/batchnorm/mul/ReadVariableOp"
#       input: "^sequential/hidden1/BiasAdd/ReadVariableOp"
#       input: "^sequential/hidden1/MatMul/ReadVariableOp"
#       input: "^sequential/hidden2/BiasAdd/ReadVariableOp"
#       input: "^sequential/hidden2/MatMul/ReadVariableOp"
#       input: "^sequential/hidden3/BiasAdd/ReadVariableOp"
#       input: "^sequential/hidden3/MatMul/ReadVariableOp"
#       input: "^sequential/output/BiasAdd/ReadVariableOp"
#       input: "^sequential/output/MatMul/ReadVariableOp"
#       attr {
#         key: "_acd_function_control_output"
#         value {
#           b: true
#         }
#       }
#     }
#     node_def {
#       name: "Identity"
#       op: "Identity"
#       input: "sequential/output/Softmax:softmax:0"
#       input: "^NoOp"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     ret {
#       key: "identity"
#       value: "Identity:output:0"
#     }
#     attr {
#       key: "_construction_context"
#       value {
#         s: "kEagerRuntime"
#       }
#     }
#     control_ret {
#       key: "sequential/batch_normalization/batchnorm/ReadVariableOp"
#       value: "sequential/batch_normalization/batchnorm/ReadVariableOp"
#     }
#     control_ret {
#       key: "sequential/batch_normalization/batchnorm/ReadVariableOp_1"
#       value: "sequential/batch_normalization/batchnorm/ReadVariableOp_1"
#     }
#     control_ret {
#       key: "sequential/batch_normalization/batchnorm/ReadVariableOp_2"
#       value: "sequential/batch_normalization/batchnorm/ReadVariableOp_2"
#     }
#     control_ret {
#       key: "sequential/batch_normalization/batchnorm/mul/ReadVariableOp"
#       value: "sequential/batch_normalization/batchnorm/mul/ReadVariableOp"
#     }
#     control_ret {
#       key: "sequential/batch_normalization_1/batchnorm/ReadVariableOp"
#       value: "sequential/batch_normalization_1/batchnorm/ReadVariableOp"
#     }
#     control_ret {
#       key: "sequential/batch_normalization_1/batchnorm/ReadVariableOp_1"
#       value: "sequential/batch_normalization_1/batchnorm/ReadVariableOp_1"
#     }
#     control_ret {
#       key: "sequential/batch_normalization_1/batchnorm/ReadVariableOp_2"
#       value: "sequential/batch_normalization_1/batchnorm/ReadVariableOp_2"
#     }
#     control_ret {
#       key: "sequential/batch_normalization_1/batchnorm/mul/ReadVariableOp"
#       value: "sequential/batch_normalization_1/batchnorm/mul/ReadVariableOp"
#     }
#     control_ret {
#       key: "sequential/batch_normalization_2/batchnorm/ReadVariableOp"
#       value: "sequential/batch_normalization_2/batchnorm/ReadVariableOp"
#     }
#     control_ret {
#       key: "sequential/batch_normalization_2/batchnorm/ReadVariableOp_1"
#       value: "sequential/batch_normalization_2/batchnorm/ReadVariableOp_1"
#     }
#     control_ret {
#       key: "sequential/batch_normalization_2/batchnorm/ReadVariableOp_2"
#       value: "sequential/batch_normalization_2/batchnorm/ReadVariableOp_2"
#     }
#     control_ret {
#       key: "sequential/batch_normalization_2/batchnorm/mul/ReadVariableOp"
#       value: "sequential/batch_normalization_2/batchnorm/mul/ReadVariableOp"
#     }
#     control_ret {
#       key: "sequential/hidden1/BiasAdd/ReadVariableOp"
#       value: "sequential/hidden1/BiasAdd/ReadVariableOp"
#     }
#     control_ret {
#       key: "sequential/hidden1/MatMul/ReadVariableOp"
#       value: "sequential/hidden1/MatMul/ReadVariableOp"
#     }
#     control_ret {
#       key: "sequential/hidden2/BiasAdd/ReadVariableOp"
#       value: "sequential/hidden2/BiasAdd/ReadVariableOp"
#     }
#     control_ret {
#       key: "sequential/hidden2/MatMul/ReadVariableOp"
#       value: "sequential/hidden2/MatMul/ReadVariableOp"
#     }
#     control_ret {
#       key: "sequential/hidden3/BiasAdd/ReadVariableOp"
#       value: "sequential/hidden3/BiasAdd/ReadVariableOp"
#     }
#     control_ret {
#       key: "sequential/hidden3/MatMul/ReadVariableOp"
#       value: "sequential/hidden3/MatMul/ReadVariableOp"
#     }
#     control_ret {
#       key: "sequential/output/BiasAdd/ReadVariableOp"
#       value: "sequential/output/BiasAdd/ReadVariableOp"
#     }
#     control_ret {
#       key: "sequential/output/MatMul/ReadVariableOp"
#       value: "sequential/output/MatMul/ReadVariableOp"
#     }
#     arg_attr {
#       key: 0
#       value {
#         attr {
#           key: "_output_shapes"
#           value {
#             list {
#               shape {
#                 dim {
#                   size: -1
#                 }
#                 dim {
#                   size: 2
#                 }
#               }
#             }
#           }
#         }
#         attr {
#           key: "_user_specified_name"
#           value {
#             s: "input"
#           }
#         }
#       }
#     }
#   }
# }
# versions {
#   producer: 898
#   min_consumer: 12
# }

# %% [markdown]
# ## Start using Docker
#
# - TensorFlow with Docker: https://github.com/tensorflow/serving/blob/master/tensorflow_serving/g3doc/docker.md
# - TFX Serving: https://www.tensorflow.org/tfx/serving/docker
# - Complete example: https://github.com/embarced/notebooks/tree/master/tfx
# - GPU support:
#   - https://www.tensorflow.org/tfx/serving/docker#serving_with_docker_using_your_gpu
#   - https://github.com/NVIDIA/nvidia-docker
#     - https://docs.nvidia.com/datacenter/cloud-native/container-toolkit/install-guide.html#docker
#   - https://docs.docker.com/compose/gpu-support/

# %%
# !curl -d '{"instances": [[50.0, 122.0], [48, 100], [30, 150]]}' -X POST http://localhost:8501/v1/models/insurance:predict
# Out:
# {
#     "predictions": [[0.184337184, 0.28695032, 0.528712511], [0.0255763717, 0.198027506, 0.776396155], [0.947066486, 0.041994229, 0.0109393876]
#     ]
# }

# %% [markdown]
# ## Load and use model from C++ server
#
# * https://github.com/tensorflow/serving
# * will run on Linux only

# %%
# !saved_model_cli show --dir classifier --all
# Out:
# MetaGraphDef with tag-set: 'serve' contains the following SignatureDefs:
#
# signature_def['__saved_model_init_op']:
#   The given SavedModel SignatureDef contains the following input(s):
#   The given SavedModel SignatureDef contains the following output(s):
#     outputs['__saved_model_init_op'] tensor_info:
#         dtype: DT_INVALID
#         shape: unknown_rank
#         name: NoOp
#   Method name is:
#
# signature_def['serving_default']:
#   The given SavedModel SignatureDef contains the following input(s):
#     inputs['input'] tensor_info:
#         dtype: DT_FLOAT
#         shape: (-1, 2)
#         name: serving_default_input:0
#   The given SavedModel SignatureDef contains the following output(s):
#     outputs['output'] tensor_info:
#         dtype: DT_FLOAT
#         shape: (-1, 3)
#         name: StatefulPartitionedCall:0
#   Method name is: tensorflow/serving/predict
#
# Defined Functions:
#   Function Name: '__call__'
#     Option #1
#       Callable with:
#         Argument #1
#           inputs: TensorSpec(shape=(None, 2), dtype=tf.float32, name='inputs')
#         Argument #2
#           DType: bool
#           Value: True
#         Argument #3
#           DType: NoneType
#           Value: None
#     Option #2
#       Callable with:
#         Argument #1
#           input: TensorSpec(shape=(None, 2), dtype=tf.float32, name='input')
#         Argument #2
#           DType: bool
#           Value: True
#         Argument #3
#           DType: NoneType
#           Value: None
#     Option #3
#       Callable with:
#         Argument #1
#           inputs: TensorSpec(shape=(None, 2), dtype=tf.float32, name='inputs')
#         Argument #2
#           DType: bool
#           Value: False
#         Argument #3
#           DType: NoneType
#           Value: None
#     Option #4
#       Callable with:
#         Argument #1
#           input: TensorSpec(shape=(None, 2), dtype=tf.float32, name='input')
#         Argument #2
#           DType: bool
#           Value: False
#         Argument #3
#           DType: NoneType
#           Value: None
#
#   Function Name: '_default_save_signature'
#     Option #1
#       Callable with:
#         Argument #1
#           input: TensorSpec(shape=(None, 2), dtype=tf.float32, name='input')
#
#   Function Name: 'call_and_return_all_conditional_losses'
#     Option #1
#       Callable with:
#         Argument #1
#           input: TensorSpec(shape=(None, 2), dtype=tf.float32, name='input')
#         Argument #2
#           DType: bool
#           Value: True
#         Argument #3
#           DType: NoneType
#           Value: None
#     Option #2
#       Callable with:
#         Argument #1
#           input: TensorSpec(shape=(None, 2), dtype=tf.float32, name='input')
#         Argument #2
#           DType: bool
#           Value: False
#         Argument #3
#           DType: NoneType
#           Value: None
#     Option #3
#       Callable with:
#         Argument #1
#           inputs: TensorSpec(shape=(None, 2), dtype=tf.float32, name='inputs')
#         Argument #2
#           DType: bool
#           Value: False
#         Argument #3
#           DType: NoneType
#           Value: None
#     Option #4
#       Callable with:
#         Argument #1
#           inputs: TensorSpec(shape=(None, 2), dtype=tf.float32, name='inputs')
#         Argument #2
#           DType: bool
#           Value: True
#         Argument #3
#           DType: NoneType
#           Value: None
# 2022-02-01 16:37:36.099018: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-02-01 16:37:36.099068: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# !mkdir insurance

# %%
# !cp -R classifier/ insurance/1

# %%
# %%bash --bg
#
# nohup tensorflow_model_server --port=8500 --rest_api_port=8501 \
#   --model_name=insurance --model_base_path=/home/olli/notebooks/mlops/insurance  >server.log 2>&1

# %%
# !tail server.log
# Out:
# nohup: failed to run command 'tensorflow_model_server': No such file or directory
